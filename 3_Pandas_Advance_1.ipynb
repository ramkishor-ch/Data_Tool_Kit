# %%
# Pandas Advance: 

import pandas as pd 

import numpy as np

# %%
# json: JavaScript Object Notation 

# json has key value pairs 

url = "https://api.github.com/repos/pandas-dev/pandas/issues"

pd.read_json(url)
# reading the json data
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0   https://github.com/pandas-dev/pandas/issues/57521  2144084011
# 1   https://github.com/pandas-dev/pandas/issues/57520  2144040421
# 2     https://github.com/pandas-dev/pandas/pull/57519  2144037974
# 3     https://github.com/pandas-dev/pandas/pull/57518  2143649322
# 4   https://github.com/pandas-dev/pandas/issues/57517  2143376452
# 5     https://github.com/pandas-dev/pandas/pull/57516  2143360560
# 6   https://github.com/pandas-dev/pandas/issues/57512  2143259336
# 7   https://github.com/pandas-dev/pandas/issues/57511  2143220186
# 8     https://github.com/pandas-dev/pandas/pull/57510  2143218042
# 9     https://github.com/pandas-dev/pandas/pull/57508  2142894312
# 10  https://github.com/pandas-dev/pandas/issues/57505  2142533685
# 11    https://github.com/pandas-dev/pandas/pull/57504  2142090284
# 12  https://github.com/pandas-dev/pandas/issues/57500  2141564011
# 13    https://github.com/pandas-dev/pandas/pull/57494  2141248587
# 14    https://github.com/pandas-dev/pandas/pull/57492  2141207431
# 15    https://github.com/pandas-dev/pandas/pull/57491  2141204830
# 16    https://github.com/pandas-dev/pandas/pull/57489  2141183560
# 17    https://github.com/pandas-dev/pandas/pull/57487  2141087697
# 18    https://github.com/pandas-dev/pandas/pull/57479  2140668961
# 19    https://github.com/pandas-dev/pandas/pull/57478  2140653286
# 20    https://github.com/pandas-dev/pandas/pull/57476  2140635039
# 21    https://github.com/pandas-dev/pandas/pull/57475  2140629857
# 22    https://github.com/pandas-dev/pandas/pull/57471  2140109143
# 23    https://github.com/pandas-dev/pandas/pull/57469  2139979734
# 24    https://github.com/pandas-dev/pandas/pull/57467  2139718597
# 25  https://github.com/pandas-dev/pandas/issues/57463  2139468884
# 26    https://github.com/pandas-dev/pandas/pull/57462  2139259674
# 27    https://github.com/pandas-dev/pandas/pull/57459  2139012377
# 28  https://github.com/pandas-dev/pandas/issues/57457  2138905886
# 29  https://github.com/pandas-dev/pandas/issues/57456  2138783039
#
#                 node_id  number  \
# 0    I_kwDOAA0YD85_zCAr   57521
# 1    I_kwDOAA0YD85_y3Xl   57520
# 2   PR_kwDOAA0YD85nYIKp   57519
# 3   PR_kwDOAA0YD85nWzJN   57518
# 4    I_kwDOAA0YD85_wVRE   57517
# 5   PR_kwDOAA0YD85nV1LZ   57516
# 6    I_kwDOAA0YD85_v4rI   57512
# 7    I_kwDOAA0YD85_vvHa   57511
# 8   PR_kwDOAA0YD85nVWvz   57510
# 9   PR_kwDOAA0YD85nUQR1   57508
# 10   I_kwDOAA0YD85_tHg1   57505
# 11  PR_kwDOAA0YD85nRfve   57504
# 12   I_kwDOAA0YD85_paxr   57500
# 13  PR_kwDOAA0YD85nOngy   57494
# 14  PR_kwDOAA0YD85nOfS4   57492
# 15  PR_kwDOAA0YD85nOexQ   57491
# 16  PR_kwDOAA0YD85nOae-   57489
# 17  PR_kwDOAA0YD85nOHeA   57487
# 18  PR_kwDOAA0YD85nMwkG   57479
# 19  PR_kwDOAA0YD85nMtmU   57478
# 20  PR_kwDOAA0YD85nMqFf   57476
# 21  PR_kwDOAA0YD85nMpGU   57475
# 22  PR_kwDOAA0YD85nKxQk   57471
# 23  PR_kwDOAA0YD85nKT7e   57469
# 24  PR_kwDOAA0YD85nJb-B   57467
# 25   I_kwDOAA0YD85_hbRU   57463
# 26  PR_kwDOAA0YD85nH18V   57462
# 27  PR_kwDOAA0YD85nG-RC   57459
# 28   I_kwDOAA0YD85_fR0e   57457
# 29   I_kwDOAA0YD85_ez0_   57456
#
#                                                 title  ... closed_at  \
# 0   BUG: pandas >= 2.0 parses 'May' in ambiguous way.  ...       NaT
# 1   Potential performance regression by commit 1e9...  ...       NaT
# 2   TST: add a test for selecting columns in DataF...  ...       NaT
# 3                       Improving function definition  ...       NaT
# 4   BUG: MultiIndex.factorize fails if index is 0-...  ...       NaT
# 5                 CI/TST: Use tmp_path for excel test  ...       NaT
# 6       BUG: Unexpected read_csv parse_dates behavior  ...       NaT
# 7          CI: excel tests started failing on windows  ...       NaT
# 8                             DOC: Fix xarray example  ...       NaT
# 9                     BUG: Tick division is incorrect  ...       NaT
# 10  BUG: `std` using `numpy.float32` dtype gives i...  ...       NaT
# 11    DOC: Fix PR01 errors in multiple files (#57438)  ...       NaT
# 12  BUG: Columns resulting from joining multiIndex...  ...       NaT
# 13  BUG: DateTimeIndex.is_year_start unexpected be...  ...       NaT
# 14  Remove dtype inference on object dtype indexes...  ...       NaT
# 15                         Remove is_foo_dtype checks  ...       NaT
# 16  REGR: astype introducing decimals when casting...  ...       NaT
# 17  CoW: Track references in unstack if there is n...  ...       NaT
# 18  PERF: Improve performance for fillna with date...  ...       NaT
# 19       PERF: Improve performance for astype is view  ...       NaT
# 20         TYP: simplify read_csv/fwf/table overloads  ...       NaT
# 21  REGR: Index.map adding back tz to tz-agnostic ...  ...       NaT
# 22  BUG: guess_datetime_format fails to infer time...  ...       NaT
# 23          DEPR: to_pytimedelta return Index[object]  ...       NaT
# 24  PERF: RangeIndex.append returns a RangeIndex w...  ...       NaT
# 25  DEPR: to_pytimedelta to return Index[object] i...  ...       NaT
# 26  REGR: Behavior differs when adding Series to f...  ...       NaT
# 27  PERF: DataFrame(ndarray) constructor ensure to...  ...       NaT
# 28  BUG: Endianness problem with weird data types ...  ...       NaT
# 29  BUG: Inconsistent date_range output when using...  ...       NaT
#
#    author_association active_lock_reason  \
# 0                NONE                NaN
# 1              MEMBER                NaN
# 2         CONTRIBUTOR                NaN
# 3                NONE                NaN
# 4         CONTRIBUTOR                NaN
# 5              MEMBER                NaN
# 6                NONE                NaN
# 7              MEMBER                NaN
# 8              MEMBER                NaN
# 9              MEMBER                NaN
# 10               NONE                NaN
# 11               NONE                NaN
# 12               NONE                NaN
# 13               NONE                NaN
# 14             MEMBER                NaN
# 15             MEMBER                NaN
# 16             MEMBER                NaN
# 17             MEMBER                NaN
# 18             MEMBER                NaN
# 19             MEMBER                NaN
# 20             MEMBER                NaN
# 21             MEMBER                NaN
# 22        CONTRIBUTOR                NaN
# 23               NONE                NaN
# 24             MEMBER                NaN
# 25             MEMBER                NaN
# 26             MEMBER                NaN
# 27             MEMBER                NaN
# 28               NONE                NaN
# 29               NONE                NaN
#
#                                                  body  \
# 0   ### Pandas version checks\n\n- [X] I have chec...
# 1   PR #57445 \r\n\r\nBenchmarks:\r\n\r\n- [ ] `gr...
# 2   - [x] closes #57457\r\n \r\nadded a test in to...
# 3   - [x] closes #57305 \r\n- [x] All [code checks...
# 4   ### Pandas version checks\n\n- [X] I have chec...
# 5   - [ ] closes #57511 (Replace xxxx with the Git...
# 6   ### Pandas version checks\n\n- [X] I have chec...
# 7   some issues with concurrent access to the same...
# 8   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 9   - [ ] closes #57264 (Replace xxxx with the Git...
# 10  ### Pandas version checks\r\n\r\n- [X] I have ...
# 11  Fixed PR01 errors (#57438) and added parameter...
# 12  ### Pandas version checks\r\n\r\n- [X] I have ...
# 13  - [ ] closes #57377\r\n- [ ] [Tests added and ...
# 14  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 15  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 16  …\r\n\r\n- [ ] closes #57418 (Replace xxxx wit...
# 17  - [ ] xref #56633\r\n- [ ] All [code checks pa...
# 18  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 19  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 20                                               None
# 21  - [x] closes #57192 (Replace xxxx with the Git...
# 22  - [x] closes #57452(Replace xxxx with the GitH...
# 23  - [x] closes #57463 \r\n- [ ] [Tests added and...
# 24  Discovered in https://github.com/pandas-dev/pa...
# 25  https://github.com/pandas-dev/pandas/pull/5245...
# 26  follow up to #56426\r\n\r\nthis was inconsiste...
# 27  Closes https://github.com/pandas-dev/pandas/is...
# 28  ### Pandas version checks\n\n- [X] I have chec...
# 29  ### Pandas version checks\r\n\r\n- [X] I have ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app  state_reason draft  \
# 0                       NaN          None   NaN
# 1                       NaN          None   NaN
# 2                       NaN          None   1.0
# 3                       NaN          None   0.0
# 4                       NaN          None   NaN
# 5                       NaN          None   0.0
# 6                       NaN          None   NaN
# 7                       NaN          None   NaN
# 8                       NaN          None   0.0
# 9                       NaN          None   0.0
# 10                      NaN          None   NaN
# 11                      NaN          None   0.0
# 12                      NaN          None   NaN
# 13                      NaN          None   0.0
# 14                      NaN          None   0.0
# 15                      NaN          None   0.0
# 16                      NaN          None   0.0
# 17                      NaN          None   0.0
# 18                      NaN          None   0.0
# 19                      NaN          None   0.0
# 20                      NaN          None   0.0
# 21                      NaN          None   1.0
# 22                      NaN          None   0.0
# 23                      NaN          None   0.0
# 24                      NaN          None   0.0
# 25                      NaN          None   NaN
# 26                      NaN          None   0.0
# 27                      NaN          None   0.0
# 28                      NaN      reopened   NaN
# 29                      NaN          None   NaN
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10                                                NaN
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 30 columns]

# %%
import requests 

# Python requests is a library for making HTTP requests. 
# check whether we can access the url or not 

data = requests.get(url) 

# <Response [200]> 
# get will return the response from the url 

df = data.json() 
df
# display the all data through json
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57521',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57521/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57521/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57521/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57521',
#   'id': 2144084011,
#   'node_id': 'I_kwDOAA0YD85_zCAr',
#   'number': 57521,
#   'title': "BUG: pandas >= 2.0 parses 'May' in ambiguous way.",
#   'user': {'login': 'ffyring',
#    'id': 12187949,
#    'node_id': 'MDQ6VXNlcjEyMTg3OTQ5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12187949?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ffyring',
#    'html_url': 'https://github.com/ffyring',
#    'followers_url': 'https://api.github.com/users/ffyring/followers',
#    'following_url': 'https://api.github.com/users/ffyring/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ffyring/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ffyring/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ffyring/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ffyring/orgs',
#    'repos_url': 'https://api.github.com/users/ffyring/repos',
#    'events_url': 'https://api.github.com/users/ffyring/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ffyring/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-20T10:46:57Z',
#   'updated_at': '2024-02-20T10:48:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfrom io import StringIO\r\n\r\ncsv_ok = """\r\nREF_DATE, VAL\r\n20-Apr-2024, 120\r\n20-May-2024, 100\r\n"""\r\n\r\ncsv_error = """\r\nREF_DATE, VAL\r\n20-May-2024, 120\r\n20-Apr-2024, 100\r\n"""\r\n\r\n# This works fine\r\ndf_ok = pd.read_csv(StringIO(csv_ok))\r\ndf_ok[\'REF_DATE\'] = pd.to_datetime(df_ok[\'REF_DATE\'])\r\ndf_ok[\'NEXT_DATE\'] = df_ok[\'REF_DATE\'] + pd.Timedelta(days=1)\r\n\r\n# This gives an error\r\ndf_error = pd.read_csv(StringIO(csv_error))\r\ndf_error[\'REF_DATE\'] = pd.to_datetime(df_error[\'REF_DATE\'])\r\ndf_error[\'NEXT_DATE\'] = df_error[\'REF_DATE\'] + pd.Timedelta(days=1)\n```\n\n\n### Issue Description\n\nCode above works with pandas<2.0 and fails with pandas>=2.0\r\n\r\nFailure occurs because pandas >= 2.0 parses the date format in second example as "%d-%B-%Y" (long datename) instead if "%d-%b-%Y" (3-letter dastename) since "May" is both the full month name and three-letter-abbreviation of the 5th month of the year.\r\n\r\nThe cause is the removal of the default argument ```infer_datetime_format=False``` in ```core.tools.datetimes._convert_listlike_datetimes```\r\nPandas>=2.0 then uses \r\n```\r\ndef _guess_datetime_format_for_array(arr, dayfirst: bool | None = False) -> str | None:\r\n    # Try to guess the format based on the first non-NaN element, return None if can\'t\r\n    if (first_non_null := tslib.first_non_null(arr)) != -1:\r\n        if type(first_non_nan_element := arr[first_non_null]) is str:  # noqa: E721\r\n            # GH#32264 np.str_ object\r\n            guessed_format = guess_datetime_format(\r\n                first_non_nan_element, dayfirst=dayfirst\r\n            )\r\n            if guessed_format is not None:\r\n                return guessed_format\r\n            # If there are multiple non-null elements, warn about\r\n            # how parsing might not be consistent\r\n            if tslib.first_non_null(arr[first_non_null + 1 :]) != -1:\r\n                warnings.warn(\r\n                    "Could not infer format, so each element will be parsed "\r\n                    "individually, falling back to `dateutil`. To ensure parsing is "\r\n                    "consistent and as-expected, please specify a format.",\r\n                    UserWarning,\r\n                    stacklevel=find_stack_level(),\r\n                )\r\n    return None\r\n```\r\n\r\nusing the ambiguous first element.\r\n\r\n\n\n### Expected Behavior\n\npandas should infer the datetime format correctly, using several entries when the format is ambiguous.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : f538741432edf55c6b9fb5d0d496d2dd1d7c2457\r\npython                : 3.11.7.final.0\r\npython-bits           : 64\r\nOS                    : Windows\r\nOS-release            : 10\r\nVersion               : 10.0.19044\r\nmachine               : AMD64\r\nprocessor             : Intel64 Family 6 Model 165 Stepping 5, GenuineIntel\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : None\r\nLOCALE                : Swedish_Sweden.1252\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.8.2\r\nsetuptools            : 69.1.0\r\npip                   : 24.0\r\nCython                : None\r\npytest                : 8.0.0\r\nhypothesis            : None\r\nsphinx                : 7.2.6\r\nblosc                 : None\r\nfeather               : None\ ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57521/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57521/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57520',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57520/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57520/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57520/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57520',
#   'id': 2144040421,
#   'node_id': 'I_kwDOAA0YD85_y3Xl',
#   'number': 57520,
#   'title': 'Potential performance regression by commit 1e9cccc: PERF Allow RangeIndex.take to return a RangeIndex when possible',
#   'user': {'login': 'DeaMariaLeon',
#    'id': 11835246,
#    'node_id': 'MDQ6VXNlcjExODM1MjQ2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11835246?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DeaMariaLeon',
#    'html_url': 'https://github.com/DeaMariaLeon',
#    'followers_url': 'https://api.github.com/users/DeaMariaLeon/followers',
#    'following_url': 'https://api.github.com/users/DeaMariaLeon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DeaMariaLeon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DeaMariaLeon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DeaMariaLeon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DeaMariaLeon/orgs',
#    'repos_url': 'https://api.github.com/users/DeaMariaLeon/repos',
#    'events_url': 'https://api.github.com/users/DeaMariaLeon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DeaMariaLeon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-20T10:24:25Z',
#   'updated_at': '2024-02-20T10:24:25Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "PR #57445 \r\n\r\nBenchmarks:\r\n\r\n- [ ] `groupby.GroupByMethods.time_dtype_as_field` (Python) with application='direct', dtype='uint', method='quantile', ncols=1, param5='cython'\r\n- [ ] `frame_methods.SortValues.time_frame_sort_values` (Python) with ascending=False\r\n- [ ] `frame_methods.SortValues.time_frame_sort_values` (Python) with ascending=True\r\n- [ ] `groupby.Groups.time_series_groups` (Python) with key='object_large'\r\n- [ ] `gil.ParallelGroups.time_get_groups` (Python) with threads=2\r\n- [ ] `gil.ParallelGroups.time_get_groups` (Python) with threads=8\r\n- [ ] `groupby.Groups.time_series_groups` (Python) with key='object_small'\r\n- [ ] `groupby.GroupByMethods.time_dtype_as_field` (Python) with application='direct', dtype='int16', method='quantile', ncols=1, param5='cython'\r\n- [ ] `join_merge.JoinIndex.time_left_outer_join_index` (Python)\r\n- [ ] `groupby.Apply.time_scalar_function_single_col` (Python) with factor=5\r\n- [ ] `groupby.Groups.time_series_groups` (Python) with key='int64_small'\r\n- [ ] `groupby.GroupByMethods.time_dtype_as_group` (Python) with application='direct', dtype='uint', method='quantile', ncols=1, param5='cython'\r\n- [ ] `groupby.Groups.time_series_groups` (Python) with key='int64_large'\r\n- [ ] `gil.ParallelGroups.time_get_groups` (Python) with threads=4\r\n\r\n![image](https://github.com/pandas-dev/pandas/assets/11835246/2da40dd0-77f6-46db-ae6e-29cab19e6c92)\r\n![image](https://github.com/pandas-dev/pandas/assets/11835246/dc734b08-87fb-4e50-b176-5e9bd251e420)\r\n\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57520/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57520/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57519',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57519/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57519/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57519/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57519',
#   'id': 2144037974,
#   'node_id': 'PR_kwDOAA0YD85nYIKp',
#   'number': 57519,
#   'title': 'TST: add a test for selecting columns in DataFrame with `big-endian` dtype',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-20T10:23:12Z',
#   'updated_at': '2024-02-20T10:23:12Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57519',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57519',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57519.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57519.patch',
#    'merged_at': None},
#   'body': '- [x] closes #57457\r\n \r\nadded a test in to check that selecting columns in DataFrame with `big-endian` dtype is supported',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57519/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57519/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57518',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57518/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57518/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57518/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57518',
#   'id': 2143649322,
#   'node_id': 'PR_kwDOAA0YD85nWzJN',
#   'number': 57518,
#   'title': 'Improving function definition',
#   'user': {'login': 'jmarintur',
#    'id': 28574023,
#    'node_id': 'MDQ6VXNlcjI4NTc0MDIz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28574023?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jmarintur',
#    'html_url': 'https://github.com/jmarintur',
#    'followers_url': 'https://api.github.com/users/jmarintur/followers',
#    'following_url': 'https://api.github.com/users/jmarintur/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jmarintur/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jmarintur/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jmarintur/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jmarintur/orgs',
#    'repos_url': 'https://api.github.com/users/jmarintur/repos',
#    'events_url': 'https://api.github.com/users/jmarintur/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jmarintur/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-20T06:42:16Z',
#   'updated_at': '2024-02-20T06:42:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57518',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57518',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57518.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57518.patch',
#    'merged_at': None},
#   'body': '- [x] closes #57305 \r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57518/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57518/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57517',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57517/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57517/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57517/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57517',
#   'id': 2143376452,
#   'node_id': 'I_kwDOAA0YD85_wVRE',
#   'number': 57517,
#   'title': 'BUG: MultiIndex.factorize fails if index is 0-length',
#   'user': {'login': 'batterseapower',
#    'id': 18488,
#    'node_id': 'MDQ6VXNlcjE4NDg4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18488?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/batterseapower',
#    'html_url': 'https://github.com/batterseapower',
#    'followers_url': 'https://api.github.com/users/batterseapower/followers',
#    'following_url': 'https://api.github.com/users/batterseapower/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/batterseapower/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/batterseapower/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/batterseapower/subscriptions',
#    'organizations_url': 'https://api.github.com/users/batterseapower/orgs',
#    'repos_url': 'https://api.github.com/users/batterseapower/repos',
#    'events_url': 'https://api.github.com/users/batterseapower/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/batterseapower/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-20T01:42:00Z',
#   'updated_at': '2024-02-20T01:42:00Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nempty_ix = pd.MultiIndex.from_product([\r\n    pd.Index([], name=\'a\', dtype=object),\r\n    pd.Index([], name=\'i\', dtype=\'f4\')\r\n])\r\nempty_ix.factorize() # Fails\r\n\r\n# Names are lost\r\npd.MultiIndex.from_product([\r\n    pd.Index([\'a\', \'b\'], name=\'a\'),\r\n    pd.Index([0, 1, 0], name=\'i\', dtype=\'f4\')\r\n]).factorize()[1].names\n```\n\n\n### Issue Description\n\nThe first example should succeed, but actually it fails:\r\n\r\n```\r\nFile ~/opt/conda/envs/mamba/envs/py3_2/lib/python3.11/site-packages/pandas/core/base.py:1203, in IndexOpsMixin.factorize(self, sort, use_na_sentinel)\r\n   1199     uniques = uniques.astype(np.float32)\r\n   1201 if isinstance(self, ABCIndex):\r\n   1202     # preserve e.g. MultiIndex\r\n-> 1203     uniques = self._constructor(uniques)\r\n   1204 else:\r\n   1205     from pandas import Index\r\nFile ~/opt/conda/envs/mamba/envs/py3_2/lib/python3.11/site-packages/pandas/core/indexes/multi.py:222, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)\r\n    219 if "name" in kwargs:\r\n    220     kwargs["names"] = kwargs.pop("name")\r\n--> 222 return meth(self_or_cls, *args, **kwargs)\r\nFile ~/opt/conda/envs/mamba/envs/py3_2/lib/python3.11/site-packages/pandas/core/indexes/multi.py:609, in MultiIndex.from_tuples(cls, tuples, sortorder, names)\r\n    607 if len(tuples) == 0:\r\n    608     if names is None:\r\n--> 609         raise TypeError("Cannot infer number of levels from empty list")\r\n    610     # error: Argument 1 to "len" has incompatible type "Hashable";\r\n    611     # expected "Sized"\r\n    612     arrays = [[]] * len(names)  # type: ignore[arg-type]\r\nTypeError: Cannot infer number of levels from empty list\r\n```\r\n\r\nProbably because of the same underlying issue, `MultiIndex.factorize` always loses the `names` of the original index. It should preserve the original names instead.\n\n### Expected Behavior\n\nFirst `factorize()` should return `(np.array([], dtype=np.intp), empty_ix)`\r\n\r\nSecond example should return `[\'a\', \'i\']` instead of `[None, None]`\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : fd3f57170aa1af588ba877e8e28c158a20a4886d\r\npython                : 3.11.6.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 4.18.0-348.20.1.el8_5.x86_64\r\nVersion               : #1 SMP Thu Mar 10 20:59:28 UTC 2022\r\nmachine               : x86_64\r\nprocessor             : x86_64\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_GB.UTF-8\r\nLOCALE                : en_GB.UTF-8\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.3\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 69.0.3\r\npip                   : 23.3.2\r\nCython                : None\r\npytest                : 7.4.4\r\nhypothesis            : None\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : 3.1.9\r\nlxml.etree            : 5.1.0\r\nhtml5lib              : 1.1\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.3\r\nIPython               : 8.20.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.3\r\nbottleneck            : 1.3.7\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec            ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57517/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57517/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57516',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57516/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57516/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57516/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57516',
#   'id': 2143360560,
#   'node_id': 'PR_kwDOAA0YD85nV1LZ',
#   'number': 57516,
#   'title': 'CI/TST: Use tmp_path for excel test',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 49254273,
#     'node_id': 'MDU6TGFiZWw0OTI1NDI3Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Excel',
#     'name': 'IO Excel',
#     'color': 'bfe5bf',
#     'default': False,
#     'description': 'read_excel, to_excel'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-20T01:19:25Z',
#   'updated_at': '2024-02-20T05:48:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57516',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57516',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57516.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57516.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #57511 (Replace xxxx with the GitHub issue number)\r\n\r\n`tm.ensure_clean` doesn't ensure files are unique if the same name is passed, but `tmp_path` ensures a test gets a unique temp path.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57516/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57516/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57512',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57512/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57512/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57512/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57512',
#   'id': 2143259336,
#   'node_id': 'I_kwDOAA0YD85_v4rI',
#   'number': 57512,
#   'title': 'BUG: Unexpected read_csv parse_dates behavior',
#   'user': {'login': 'kounoupis',
#    'id': 861901,
#    'node_id': 'MDQ6VXNlcjg2MTkwMQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/861901?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kounoupis',
#    'html_url': 'https://github.com/kounoupis',
#    'followers_url': 'https://api.github.com/users/kounoupis/followers',
#    'following_url': 'https://api.github.com/users/kounoupis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kounoupis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kounoupis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kounoupis/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kounoupis/orgs',
#    'repos_url': 'https://api.github.com/users/kounoupis/repos',
#    'events_url': 'https://api.github.com/users/kounoupis/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kounoupis/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-19T22:57:34Z',
#   'updated_at': '2024-02-20T09:08:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n#!/opt/apps/anaconda3/bin/python\r\n\r\nimport pandas\r\nfrom io import StringIO\r\n\r\nif __name__ == "__main__":\r\n    csv = StringIO(\'\'\'\r\nTicker,Last Update Timestamp\r\nAAA,01/29/2024 17:04:19\r\nAAA,01/30/2024 04:19:57\r\nABEQ,02/08/2024 14:33:51\r\nABEQ,02/06/2024 15:04:57\r\nABEQ,02/13/2024 07:53:11\r\n    \'\'\')\r\n\r\n    columns={\'Ticker\': str, \'Last Update Timestamp\': str}\r\n\r\n    df = pandas.read_csv(csv, usecols=columns.keys(), dtype=columns, parse_dates=[\'Last Update Timestamp\'])\r\n\r\n    print(pandas.__version__)\r\n    print(df)\n```\n\n\n### Issue Description\n\nparse_dates in combination with dtype does not correctly identify date column as a DateTime object and, in addition, converts the column into int64 (that are not even valid epochs).\r\n\r\nThis used to work correctly with pandas 1.4.0\r\n\r\nThe output of the above example is:\r\n```\r\n2.2.0\r\n  Ticker Last Update Timestamp\r\n0    AAA   1706547859000000000\r\n1    AAA   1706588397000000000\r\n2   ABEQ   1707402831000000000\r\n3   ABEQ   1707231897000000000\r\n4   ABEQ   1707810791000000000\r\n```\n\n### Expected Behavior\n\n```\r\n#!/opt/apps/anaconda3/bin/python\r\n\r\nimport pandas\r\nfrom io import StringIO\r\n\r\nif __name__ == "__main__":\r\n    csv = StringIO(\'\'\'\r\nTicker,Last Update Timestamp\r\nAAA,01/29/2024 17:04:19\r\nAAA,01/30/2024 04:19:57\r\nABEQ,02/08/2024 14:33:51\r\nABEQ,02/06/2024 15:04:57\r\nABEQ,02/13/2024 07:53:11\r\n    \'\'\')\r\n\r\n    columns={\'Ticker\': str, \'Last Update Timestamp\': str}\r\n\r\n    df = pandas.read_csv(csv, parse_dates=[\'Last Update Timestamp\'])\r\n\r\n    print(pandas.__version__)\r\n    print(df)\r\n\r\n```\r\n\r\nOutput:\r\n```\r\n> ./date.py\r\n2.2.0\r\n  Ticker Last Update Timestamp\r\n0    AAA   2024-01-29 17:04:19\r\n1    AAA   2024-01-30 04:19:57\r\n2   ABEQ   2024-02-08 14:33:51\r\n3   ABEQ   2024-02-06 15:04:57\r\n4   ABEQ   2024-02-13 07:53:11\r\n```\n\n### Installed Versions\n\n<details>\r\n\r\n/opt/apps/anaconda3/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : f538741432edf55c6b9fb5d0d496d2dd1d7c2457\r\npython                : 3.11.6.final.0\r\npython-bits           : 64\r\nOS                    : Linux\r\nOS-release            : 5.10.0-9-amd64\r\nVersion               : #1 SMP Debian 5.10.70-1 (2021-09-30)\r\nmachine               : x86_64\r\nprocessor             : \r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : en_US.UTF-8\r\nLOCALE                : en_US.UTF-8\r\n\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.4\r\npytz                  : 2024.1\r\ndateutil              : 2.8.2\r\nsetuptools            : 69.0.3\r\npip                   : 24.0\r\nCython                : None\r\npytest                : 8.0.0\r\nhypothesis            : None\r\nsphinx                : 7.2.6\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : 3.1.9\r\nlxml.etree            : 4.9.3\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.3\r\nIPython               : 8.21.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.3\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfast ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57512/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57512/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57511',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57511/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57511/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57511/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57511',
#   'id': 2143220186,
#   'node_id': 'I_kwDOAA0YD85_vvHa',
#   'number': 57511,
#   'title': 'CI: excel tests started failing on windows',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-19T22:13:26Z',
#   'updated_at': '2024-02-19T22:14:04Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'some issues with concurrent access to the same file not possible on windows\r\n\r\nPR that circumvented this is here: \r\n\r\nhttps://github.com/pandas-dev/pandas/pull/57486',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57511/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57511/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57510',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57510/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57510/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57510/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57510',
#   'id': 2143218042,
#   'node_id': 'PR_kwDOAA0YD85nVWvz',
#   'number': 57510,
#   'title': 'DOC: Fix xarray example',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/116',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116/labels',
#    'id': 10403366,
#    'node_id': 'MI_kwDOAA0YD84Anr4m',
#    'number': 116,
#    'title': '2.2.1',
#    'description': 'on-merge: backport to 2.2.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 44,
#    'closed_issues': 123,
#    'state': 'open',
#    'created_at': '2024-01-11T01:47:31Z',
#    'updated_at': '2024-02-20T01:20:20Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-19T22:11:36Z',
#   'updated_at': '2024-02-19T23:42:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57510',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57510',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57510.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57510.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57510/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57510/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57508',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57508/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57508/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57508/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57508',
#   'id': 2142894312,
#   'node_id': 'PR_kwDOAA0YD85nUQR1',
#   'number': 57508,
#   'title': 'BUG: Tick division is incorrect',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False,
#     'description': 'DateOffsets'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-19T17:49:37Z',
#   'updated_at': '2024-02-19T22:18:38Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57508',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57508',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57508.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57508.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #57264 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57508/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57508/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57505',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57505/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57505/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57505/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57505',
#   'id': 2142533685,
#   'node_id': 'I_kwDOAA0YD85_tHg1',
#   'number': 57505,
#   'title': 'BUG: `std` using `numpy.float32` dtype gives incorrect result on contant array.',
#   'user': {'login': 'jamespreed',
#    'id': 7841701,
#    'node_id': 'MDQ6VXNlcjc4NDE3MDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7841701?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jamespreed',
#    'html_url': 'https://github.com/jamespreed',
#    'followers_url': 'https://api.github.com/users/jamespreed/followers',
#    'following_url': 'https://api.github.com/users/jamespreed/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jamespreed/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jamespreed/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jamespreed/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jamespreed/orgs',
#    'repos_url': 'https://api.github.com/users/jamespreed/repos',
#    'events_url': 'https://api.github.com/users/jamespreed/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jamespreed/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 9,
#   'created_at': '2024-02-19T14:44:41Z',
#   'updated_at': '2024-02-20T03:29:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2024-02-16T17:01:18Z',
#   'updated_at': '2024-02-19T13:10:01Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57459',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57459',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57459.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57459.patch',
#    'merged_at': None},
#   'body': 'Closes https://github.com/pandas-dev/pandas/issues/50756\r\n\r\nxref https://github.com/pandas-dev/pandas/issues/57431\r\n\r\nWith CoW enabled now, the default behaviour of `DataFrame(ndarray)` is to copy the numpy array (before 3.0, this would not copy the data). However, if we do a copy, we should also make sure we copy it to the optimal layout (typically column major). Before CoW, this copy would often happen later on anyway, and an explicit `copy()` actually does ensure column-major layout:\r\n\r\nOn main:\r\n```\r\n>>> arr = np.random.randn(10, 3)\r\n>>> df = pd.DataFrame(arr)  # does actually make a copy of `arr` under the hood\r\n>>> df._mgr.blocks[0].values.flags.c_contiguous\r\nFalse\r\n>>> df2 = df.copy()  # explicit copy method\r\n>>> df2._mgr.blocks[0].values.flags.c_contiguous\r\nTrue\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57459/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57459/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57457',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57457/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57457/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57457/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57457',
#   'id': 2138905886,
#   'node_id': 'I_kwDOAA0YD85_fR0e',
#   'number': 57457,
#   'title': 'BUG: Endianness problem with weird data types and shape',
#   'user': {'login': 'ilan-gold',
#    'id': 43999641,
#    'node_id': 'MDQ6VXNlcjQzOTk5NjQx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43999641?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ilan-gold',
#    'html_url': 'https://github.com/ilan-gold',
#    'followers_url': 'https://api.github.com/users/ilan-gold/followers',
#    'following_url': 'https://api.github.com/users/ilan-gold/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ilan-gold/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ilan-gold/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ilan-gold/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ilan-gold/orgs',
#    'repos_url': 'https://api.github.com/users/ilan-gold/repos',
#    'events_url': 'https://api.github.com/users/ilan-gold/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ilan-gold/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None},
#    {'id': 986278782,
#     'node_id': 'MDU6TGFiZWw5ODYyNzg3ODI=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Tests',
#     'name': 'Needs Tests',
#     'color': 'cdea3c',
#     'default': False,
#     'description': 'Unit test(s) needed to prevent regressions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2024-02-16T15:58:37Z',
#   'updated_at': '2024-02-19T13:23:18Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd, numpy as np\r\n\r\ncolumns = [\'\']\r\ndata = [np.array([], dtype=\'>f8\')]\r\nindex = pd.Index([], dtype=\'uint64\', name=\'rows\')\r\ndf = pd.DataFrame(dict(zip(columns, data)), index=index)\r\ndf[df.columns] # or df[[\'\']]\n```\n\n\n### Issue Description\n\nI\'m actually not 100% this is a "bug", but it came up in a `hypothesis` test and I whittled it down to this.   The error is `ValueError: Big-endian buffer not supported on little-endian compiler`\n\n### Expected Behavior\n\nI guess it shouldn\'t error?\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit                : fd3f57170aa1af588ba877e8e28c158a20a4886d\r\npython                : 3.11.6.final.0\r\npython-bits           : 64\r\nOS                    : Darwin\r\nOS-release            : 22.6.0\r\nVersion               : Darwin Kernel Version 22.6.0: Wed Oct  4 21:26:23 PDT 2023; root:xnu-8796.141.3.701.17~4/RELEASE_ARM64_T6000\r\nmachine               : arm64\r\nprocessor             : arm\r\nbyteorder             : little\r\nLC_ALL                : None\r\nLANG                  : None\r\nLOCALE                : None.UTF-8\r\n\r\npandas                : 2.2.0\r\nnumpy                 : 1.26.3\r\npytz                  : 2023.3.post1\r\ndateutil              : 2.8.2\r\nsetuptools            : 68.2.2\r\npip                   : 23.3.1\r\nCython                : 3.0.8\r\npytest                : 7.4.4\r\nhypothesis            : None\r\nsphinx                : None\r\nblosc                 : None\r\nfeather               : None\r\nxlsxwriter            : None\r\nlxml.etree            : None\r\nhtml5lib              : None\r\npymysql               : None\r\npsycopg2              : None\r\njinja2                : 3.1.3\r\nIPython               : 8.20.0\r\npandas_datareader     : None\r\nadbc-driver-postgresql: None\r\nadbc-driver-sqlite    : None\r\nbs4                   : 4.12.2\r\nbottleneck            : None\r\ndataframe-api-compat  : None\r\nfastparquet           : None\r\nfsspec                : 2023.12.2\r\ngcsfs                 : None\r\nmatplotlib            : 3.8.2\r\nnumba                 : 0.58.1\r\nnumexpr               : None\r\nodfpy                 : None\r\nopenpyxl              : 3.1.2\r\npandas_gbq            : None\r\npyarrow               : None\r\npyreadstat            : None\r\npython-calamine       : None\r\npyxlsb                : None\r\ns3fs                  : None\r\nscipy                 : 1.11.4\r\nsqlalchemy            : None\r\ntables                : None\r\ntabulate              : None\r\nxarray                : None\r\nxlrd                  : None\r\nzstandard             : None\r\ntzdata                : 2023.4\r\nqtpy                  : None\r\npyqt5                 : None\r\n\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57457/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57457/timeline',
#   'performed_via_github_app': None,
#   'state_reason': 'reopened'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57456',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57456/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57456/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57456/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57456',
#   'id': 2138783039,
#   'node_id': 'I_kwDOAA0YD85_ez0_',
#   'number': 57456,
#   'title': 'BUG: Inconsistent date_range output when using CustomBusinessDay as freq',
#   'user': {'login': 'blueharen',
#    'id': 26574211,
#    'node_id': 'MDQ6VXNlcjI2NTc0MjEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26574211?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/blueharen',
#    'html_url': 'https://github.com/blueharen',
#    'followers_url': 'https://api.github.com/users/blueharen/followers',
#    'following_url': 'https://api.github.com/users/blueharen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/blueharen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/blueharen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/blueharen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/blueharen/orgs',
#    'repos_url': 'https://api.github.com/users/blueharen/repos',
#    'events_url': 'https://api.github.com/users/blueharen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/blueharen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-02-16T14:52:33Z',
#   'updated_at': '2024-02-19T20:39:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nfrom pandas.tseries.offsets import CustomBusinessDay\r\nfrom datetime import datetime\r\n\r\noffset = CustomBusinessDay(weekmask='Sun Mon Tue Wed Thu')\r\nstart = datetime(2024, 2, 8, 23)\r\nend = datetime(2024, 2, 16, 14)\r\nd_range = pd.date_range(start, end, freq=offset)\r\nprint(d_range)\r\n#DatetimeIndex(['2024-02-08 23:00:00', '2024-02-11 23:00:00',\r\n#               '2024-02-12 23:00:00', '2024-02-13 23:00:00',\r\n#               '2024-02-14 23:00:00'],\r\n#              dtype='datetime64[ns]', freq='C')\r\n\r\nstart = datetime(2024, 2, 9, 23)\r\nd_range = pd.date_range(start, end, freq=offset)\r\nprint(d_range)\r\n#DatetimeIndex(['2024-02-11 23:00:00', '2024-02-12 23:00:00',\r\n#               '2024-02-13 23:00:00', '2024-02-14 23:00:00',\r\n#               '2024-02-15 23:00:00'],\r\n#              dtype='datetime64[ns]', freq='C')\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nThe last date generated from `date_range` with `start = datetime(2024, 2, 8, 23)` does not equal the last date generated from `date_range` when `start = datetime(2024, 2, 9, 23)`, other arguments unchanged. \r\n\r\nWhen the start date falls on a day within the weekmask in `CustomBusinessDay`, `date_range` output does not include 2024-02-15 (Thursday). However, when the start date is on a day not included in the weekmask (Friday or Saturday), `date_range` does include 2024-02-15.\r\n\r\n### Expected Behavior\r\n\r\nWith a freq of `CustomBusinessDay(weekmask='Sun Mon Tue Wed Thu')` and an end of 2024-02-16, I'd expect `date_range` to always include 2024-02-15, regardless of start.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 141 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.24.3\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 58.1.0\r\npip              : 24.0\r\nCython           : 0.29.32\r\npytest           : 7.2.1\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : 1.1\r\npymysql          : 1.0.2\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : 8.4.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.5.3\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.1.1\r\npandas_gbq       : None\r\npyarrow          : 15.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.0\r\nsnappy           : None\r\nsqlalchemy       : 2.0.12\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57456/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57456/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
for i in range(len(df)): 
    print(df[i]['user']['node_id']) 

# printing the data from json
# Out:
# MDQ6VXNlcjI4NTc0MDIz
# MDQ6VXNlcjE4NDg4
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjg2MTkwMQ==
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjQ3OTYzMjE1
# MDQ6VXNlcjc4NDE3MDE=
# MDQ6VXNlcjgwMjM4ODcx
# MDQ6VXNlcjYzNTAwMjc=
# U_kgDOBaGsqw
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjY2MTgxNjY=
# MDQ6VXNlcjQ1NTYyNDAy
# MDQ6VXNlcjQ3MDMyNTYz
# MDQ6VXNlcjcwMjIwNzYw
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwMjA0OTY=
# MDQ6VXNlcjQzOTk5NjQx
# MDQ6VXNlcjI2NTc0MjEx
# MDQ6VXNlcjExNDA2MDAy
# U_kgDOCI-v2Q
# MDQ6VXNlcjUzOTU2ODYz

# %%
# convert data into dataframe 
dd = pd.DataFrame(df, columns=['user','timeline_url'])

# %%
dd.to_csv('json_info.csv', index=False) 
# saving json into csv file

# %%
# Real Data Set

#Solving the dataset

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df

# PassengerId 
# Surviveid : alive or dead 
# Pclass : passenger class 
# SibSp : sibilings 
# Parch : parents or chilren 
# Embarked : which city they are boarding from 
# Cabin : seating
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head() 
# first 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() 
# last 5 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# data types
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info() 
# reading information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe() 
# statistical check of describing numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Thought process:
# read data => understand data => business understanding of data

# Row: count 
# number of passengers or number of people or number of rows onboarded 
# Age column has 714 number contains missing values when compared to 891 number in these columns(PassengerId, Survived, Pclass, Age, SibSp, Parch, Fare ) 

# Row: mean 
# passengerId column: mean does seems to meaningful think it
# IGNORE passengerId column for ALL ROWS because doesn't seems to be meaningful
# age column  
# average age of a person who has onboarded is 29.6 

# Row: std 
# age column has 14.5 
# standard deviation : how far all data points is away from mean value 
# on average each of the data point is deviating from mean value of 14.5 units 

# Row: min 
# age column has 0.42 
# minimum children age is 0.42(4 months 20 days) 
# how many childrens are below 5 years were survived/died?  
# above statement is meaning for row: min 

# Row: 25% 
# age column has 20.1 
# 25% of people below 20.1 years old 

# Row: 50% 
# age column has 28.00 
# 50% of people less than or equal to 28.00 years old 

# Row: 75% 
# age column has 38.00 
# 75% of people less than or equal to 38.00 years old 
# 75% means 75% of population , where 25%, 50% will come under 75%

# Row: max 
# age column has 80.0 
# onboarded oldest person age is 80.0(years) 


# Fare column
# Following Rows :  
# count : 891 people onboarded 
# mean : 32.2 avg fare 
# std : standard deviation 49.6 pounds paid 

# 5 points summary in statistics class for following	 
# min : children has no fare so 0.00 
# 25% :  
# 50% :
# 75% : 
# max : max fare paid by person is 512.3 pounds

# %%
df.columns 
# know about columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId','Survived','Pclass']] 
# subset of data into data frame
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
type(df.dtypes) 
# series
# Out:
# pandas.core.series.Series

# %%
df.dtypes 
# shows columns with data types
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == 'object' 
# object or string both are same
# datatypes provide all object columns
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# df.dtypes[df.dtypes == 'object']
"""
Name        object
Sex         object
Ticket      object
Cabin       object
Embarked    object
dtype: object
"""

df.dtypes[df.dtypes == 'object'].index 
# index is for index column 
# seperating all string or object columns
# Index(['Name','Sex','Ticket','Cabin','Embarked'], dtype='object')
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# df[df.dtypes[df.dtypes == 'object'].index] 
# get data frame directly 

# or  

df[df.columns[df.dtypes == 'object']] 
# get data frame directly through columns
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# 4              373450   NaN        S
# ..                ...   ...      ...
# 886            211536   NaN        S
# 887            112053   B42        S
# 888        W./C. 6607   NaN        S
# 889            111369  C148        C
# 890            370376   NaN        Q
#
# [891 rows x 5 columns]

# %%
# df[df.dtypes[df.dtypes != 'object'].index].describe() 
# get data frame directly of INTEGER columns and get statistical data 

# or  

df[df.columns[df.dtypes != 'object']].describe() 
# get data frame directly through columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Row: count
# Column: 891 Names are there
# Column: 891 males and females are there
# Column: 891 tickets
# Column: Cabin 204 means, 204 is null value or cabin is shared by multiple passengers
# Column: 889 Embarked means 889 people are boarded

# Row: Unique
# Column: 891 Names
# Column: only male and female are there in Sex 
# Column: 681 Tickets remaining where children doesn't have tickets
# Column: 147 unique Cabins are there
# Column: 3 Embarked means only 3 unique places people are boarded

# Row: top
# top row means first letter occured 
# Column: Name is first name occured Braund Mr. Owen Harris 
# Column: first gender is male 
# Column: first ticket occured 347082 ticket number
# Column: first cabin allocated B96 B98
# Column: first city onboarded S is southhampton is the city 


# Row: freq 
# freq row means how much top row has occured
# freq row is highest in the alphabet 
# Column: Name is 1 is first row from table with name 
# Column: Sex is 577 are males remaining females 
# Column: Ticket is 1 ticket 7 family members 
# Column: Cabin is B96 B98 each cabin can have 4 members 
# Column: embarked is S means southhampton is the city where 644 people onboarded 

# mostly rows like top and freq are not used much ONLY rows mostly used are count, unique 

# df[df.columns[df.dtypes == 'object']].describe() 

# or 

df.describe(include = 'object') 
# get data frame directly through columns,
# describe the data related string column
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.describe(include = 'all') 
# can get description for numerical, string, categorical
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df.astype('object').describe() 
# all df columns convert from object and then describe it.
# convert all object columns to the column type called integer,
# numerical column want to know stastical properties count, unique and freq: number of occurences
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
df.describe()
# numerical column describe
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Slicing 
df[1:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df[10:100]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..          ...       ...     ...                                   ...
# 95           96         0       3           Shorney, Mr. Charles Joseph
# 96           97         0       1             Goldschmidt, Mr. George B
# 97           98         1       1       Greenfield, Mr. William Bertram
# 98           99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99          100         0       2                     Kantor, Mr. Sinai
#
#        Sex   Age  SibSp  Parch     Ticket     Fare    Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000       G6        S
# 11  female  58.0      0      0     113783  26.5500     C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500      NaN        S
# 13    male  39.0      1      5     347082  31.2750      NaN        S
# 14  female  14.0      0      0     350406   7.8542      NaN        S
# ..     ...   ...    ...    ...        ...      ...      ...      ...
# 95    male   NaN      0      0     374910   8.0500      NaN        S
# 96    male  71.0      0      0   PC 17754  34.6542       A5        C
# 97    male  23.0      0      1   PC 17759  63.3583  D10 D12        C
# 98  female  34.0      0      1     231919  23.0000      NaN        S
# 99    male  34.0      1      0     244367  26.0000      NaN        S
#
# [90 rows x 12 columns]

# %%
df[10:100:2] 
# alternate rows
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# 62           63         0       1
# 64           65         0       1
# 66           67         1       2
# 68           69         1       3
# 70           71         0       2
# 72           73         0       2
# 74           75         1       3
# 76           77         0       3
# 78           79         1       2
# 80           81         0       3
# 82           83         1       3
# 84           85         1       2
# 86           87         0       3
# 88           89         1       1
# 90           91         0       3
# 92           93         0       1
# 94           95         0       3
# 96           97         0       1
# 98           99         1       2
#
#                                                  Name     Sex    Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 12                     Saundercock, Mr. William Henry    male  20.00      0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.00      0
# 16                               Rice, Master. Eugene    male   2.00      4
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.00      1
# 20                               Fynney, Mr. Joseph J    male  35.00      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.00      0
# 24                      Palsson, Miss. Torborg Danira  female   8.00      3
# 26                            Emir, Mr. Farred Chehab    male    NaN      0
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female    NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.00      0
# 32                           Glynn, Miss. Mary Agatha  female    NaN      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.00      1
# 36                                   Mamee, Mr. Hanna    male    NaN      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.00      2
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00      1
# 42                                Kraeff, Mr. Theodor    male    NaN      0
# 44                      Devaney, Miss. Margaret Delia  female  19.00      0
# 46                                  Lennon, Mr. Denis    male    NaN      1
# 48                                Samaan, Mr. Youssef    male    NaN      2
# 50                         Panula, Master. Juha Niilo    male   7.00      4
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.00      0
# 56                                  Rugg, Miss. Emily  female  21.00      0
# 58                       West, Miss. Constance Mirium  female   5.00      1
# 60                              Sirayanian, Mr. Orsen    male  22.00      0
# 62                        Harris, Mr. Henry Birkhardt    male  45.00      1
# 64                              Stewart, Mr. Albert A    male    NaN      0
# 66                       Nye, Mrs. (Elizabeth Ramell)  female  29.00      0
# 68                    Andersson, Miss. Erna Alexandra  female  17.00      4
# 70                         Jenkin, Mr. Stephen Curnow    male  32.00      0
# 72                               Hood, Mr. Ambrose Jr    male  21.00      0
# 74                                      Bing, Mr. Lee    male  32.00      0
# 76                                  Staneff, Mr. Ivan    male    NaN      0
# 78                      Caldwell, Master. Alden Gates    male   0.83      0
# 80                               Waelens, Mr. Achille    male  22.00      0
# 82                     McDermott, Miss. Brigdet Delia  female    NaN      0
# 84                                Ilett, Miss. Bertha  female  17.00      0
# 86                             Ford, Mr. William Neal    male  16.00      1
# 88                         Fortune, Miss. Mabel Helen  female  23.00      3
# 90                               Christmann, Mr. Emil    male  29.00      0
# 92                        Chaffee, Mr. Herbert Fuller    male  46.00      1
# 94                                  Coxon, Mr. Daniel    male  59.00      0
# 96                          Goldschmidt, Mr. George B    male  71.00      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.00      0
#
#     Parch        Ticket      Fare        Cabin Embarked
# 10      1       PP 9549   16.7000           G6        S
# 12      0     A/5. 2151    8.0500          NaN        S
# 14      0        350406    7.8542          NaN        S
# 16      1        382652   29.1250          NaN        Q
# 18      0        345763   18.0000          NaN        S
# 20      0        239865   26.0000          NaN        S
# 22      0        330923    8.0292          NaN        Q
# 24      1        349909   21.0750          NaN        S
# 26      0          2631    7.2250          NaN        C
# 28      0        330959    7.8792          NaN        Q
# 30      0      PC 17601   27.7208          NaN        C
# 32      0        335677    7.7500          NaN        Q
# 34      0      PC 17604   82.1708          NaN        C
# 36      0          2677    7.2292          NaN        C
# 38      0        345764   18.0000          NaN        S
# 40      0          7546    9.4750          NaN        S
# 42      0        349253    7.8958          NaN        C
# 44      0        330958    7.8792          NaN        Q
# 46      0        370371   15.5000          NaN        Q
# 48      0          2662   21.6792          NaN        C
# 50      1       3101295   39.6875          NaN        S
# 52      0      PC 17572   76.7292          D33        C
# 54      1        113509   61.9792          B30        C
# 56      0    C.A. 31026   10.5000          NaN        S
# 58      2    C.A. 34651   27.7500          NaN        S
# 60      0          2669    7.2292          NaN        C
# 62      0         36973   83.4750          C83        S
# 64      0      PC 17605   27.7208          NaN        C
# 66      0    C.A. 29395   10.5000          F33        S
# 68      2       3101281    7.9250          NaN        S
# 70      0    C.A. 33111   10.5000          NaN        S
# 72      0  S.O.C. 14879   73.5000          NaN        S
# 74      0          1601   56.4958          NaN        S
# 76      0        349208    7.8958          NaN        S
# 78      2        248738   29.0000          NaN        S
# 80      0        345767    9.0000          NaN        S
# 82      0        330932    7.7875          NaN        Q
# 84      0    SO/C 14885   10.5000          NaN        S
# 86      3    W./C. 6608   34.3750          NaN        S
# 88      2         19950  263.0000  C23 C25 C27        S
# 90      0        343276    8.0500          NaN        S
# 92      0   W.E.P. 5734   61.1750          E31        S
# 94      0        364500    7.2500          NaN        S
# 96      0      PC 17754   34.6542           A5        C
# 98      1        231919   23.0000          NaN        S

# %%
# make new column with new name ram 
df['new_col']='ram' 

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col
# 0        0         A/5 21171   7.2500   NaN        S     ram
# 1        0          PC 17599  71.2833   C85        C     ram
# 2        0  STON/O2. 3101282   7.9250   NaN        S     ram
# 3        0            113803  53.1000  C123        S     ram
# 4        0            373450   8.0500   NaN        S     ram
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S     ram
# 887      0            112053  30.0000   B42        S     ram
# 888      2        W./C. 6607  23.4500   NaN        S     ram
# 889      0            111369  30.0000  C148        C     ram
# 890      0            370376   7.7500   NaN        Q     ram
#
# [891 rows x 13 columns]

# %%
# make a new column called family based on existing columns 
df['family'] = df['SibSp'] + df['Parch'] 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 0        0         A/5 21171   7.2500   NaN        S     ram       1
# 1        0          PC 17599  71.2833   C85        C     ram       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S     ram       0
# 3        0            113803  53.1000  C123        S     ram       1
# 4        0            373450   8.0500   NaN        S     ram       0
# ..     ...               ...      ...   ...      ...     ...     ...
# 886      0            211536  13.0000   NaN        S     ram       0
# 887      0            112053  30.0000   B42        S     ram       0
# 888      2        W./C. 6607  23.4500   NaN        S     ram       3
# 889      0            111369  30.0000  C148        C     ram       0
# 890      0            370376   7.7500   NaN        Q     ram       0
#
# [891 rows x 14 columns]

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
# numerical column 
pd.Categorical(df['Pclass']) 

# treated Pclass column as categorical column 
# length: 891 rows 
# Categories (3, int64): [1,2,3], 3 unique values
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
# string column 
pd.Categorical(df['Cabin']) 

# treated Cabin column as categorical column 
# length: 891 rows 
# Categories (147, object): ['A10','A14',...,'T'], 147 unique values
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique() 
# provides the all unique values
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148'], dtype=object)

# %%
df['Cabin'].nunique() 
# provides number of unique values
# Out:
# 147

# %%
df['Cabin'].value_counts() 
# check which cabin is repeated how many times
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
#Question: check how many childrens are less than 5 years old 
df[df['Age'] < 5 ]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# 184          185         1       3       Kink-Heilmann, Miss. Luise Gretchen
# 193          194         1       2                Navratil, Master. Michel M
# 205          206         0       3                Strom, Miss. Telma Matilda
# 261          262         1       3         Asplund, Master. Edvin Rojj Felix
# 297          298         0       1              Allison, Miss. Helen Loraine
# 305          306         1       1            Allison, Master. Hudson Trevor
# 340          341         1       2            Navratil, Master. Edmond Roger
# 348          349         1       3    Coutts, Master. William Loch "William"
# 374          375         0       3                Palsson, Miss. Stina Viola
# 381          382         1       3               Nakid, Miss. Maria ("Mary")
# 386          387         0       3           Goodwin, Master. Sidney Leonard
# 407          408         1       2            Richards, Master. William Rowe
# 445          446         1       1                 Dodge, Master. Washington
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 479          480         1       3                  Hirvonen, Miss. Hildur E
# 530          531         1       2                  Quick, Miss. Phyllis May
# 618          619         1       2               Becker, Miss. Marion Louise
# 642          643         0       3             Skoog, Miss. Margit Elizabeth
# 644          645         1       3                    Baclini, Miss. Eugenie
# 691          692         1       3                        Karun, Miss. Manca
# 750          751         1       2                         Wells, Miss. Joan
# 755          756         1       2                 Hamalainen, Master. Viljo
# 788          789         1       3                Dean, Master. Bertram Vere
# 803          804         1       3           Thomas, Master. Assad Alexander
# 824          825         0       3              Panula, Master. Urho Abraham
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 869          870         1       3           Johnson, Master. Harold Theodor
#
#         Sex   Age  SibSp  Parch           Ticket      Fare    Cabin Embarked  \
# 7      male  2.00      3      1           349909   21.0750      NaN        S
# 10   female  4.00      1      1          PP 9549   16.7000       G6        S
# 16     male  2.00      4      1           382652   29.1250      NaN        Q
# 43   female  3.00      1      2    SC/Paris 2123   41.5792      NaN        C
# 63     male  4.00      3      2           347088   27.9000      NaN        S
# 78     male  0.83      0      2           248738   29.0000      NaN        S
# 119  female  2.00      4      2           347082   31.2750      NaN        S
# 164    male  1.00      4      1          3101295   39.6875      NaN        S
# 171    male  4.00      4      1           382652   29.1250      NaN        Q
# 172  female  1.00      1      1           347742   11.1333      NaN        S
# 183    male  1.00      2      1           230136   39.0000       F4        S
# 184  female  4.00      0      2           315153   22.0250      NaN        S
# 193    male  3.00      1      1           230080   26.0000       F2        S
# 205  female  2.00      0      1           347054   10.4625       G6        S
# 261    male  3.00      4      2           347077   31.3875      NaN        S
# 297  female  2.00      1      2           113781  151.5500  C22 C26        S
# 305    male  0.92      1      2           113781  151.5500  C22 C26        S
# 340    male  2.00      1      1           230080   26.0000       F2        S
# 348    male  3.00      1      1       C.A. 37671   15.9000      NaN        S
# 374  female  3.00      3      1           349909   21.0750      NaN        S
# 381  female  1.00      0      2             2653   15.7417      NaN        C
# 386    male  1.00      5      2          CA 2144   46.9000      NaN        S
# 407    male  3.00      1      1            29106   18.7500      NaN        S
# 445    male  4.00      0      2            33638   81.8583      A34        S
# 469  female  0.75      2      1             2666   19.2583      NaN        C
# 479  female  2.00      0      1          3101298   12.2875      NaN        S
# 530  female  2.00      1      1            26360   26.0000      NaN        S
# 618  female  4.00      2      1           230136   39.0000       F4        S
# 642  female  2.00      3      2           347088   27.9000      NaN        S
# 644  female  0.75      2      1             2666   19.2583      NaN        C
# 691  female  4.00      0      1           349256   13.4167      NaN        C
# 750  female  4.00      1      1            29103   23.0000      NaN        S
# 755    male  0.67      1      1           250649   14.5000      NaN        S
# 788    male  1.00      1      2        C.A. 2315   20.5750      NaN        S
# 803    male  0.42      0      1             2625    8.5167      NaN        C
# 824    male  2.00      4      1          3101295   39.6875      NaN        S
# 827    male  1.00      0      2  S.C./PARIS 2079   37.0042      NaN        C
# 831    male  0.83      1      1            29106   18.7500      NaN        S
# 850    male  4.00      4      2           347082   31.2750      NaN        S
# 869    male  4.00      1      1           347742   11.1333      NaN        S
#
#     new_col  family
# 7       ram       4
# 10      ram       2
# 16      ram       5
# 43      ram       3
# 63      ram       5
# 78      ram       2
# 119     ram       6
# 164     ram       5
# 171     ram       5
# 172     ram       2
# 183     ram       3
# 184     ram       2
# 193     ram       2
# 205     ram       1
# 261     ram       6
# 297     ram       3
# 305     ram       3
# 340     ram       2
# 348     ram       2
# 374     ram       4
# 381     ram       2
# 386     ram       7
# 407     ram       2
# 445     ram       2
# 469     ram       3
# 479     ram       1
# 530     ram       2
# 618     ram       3
# 642     ram       5
# 644     ram       3
# 691     ram       1
# 750     ram       2
# 755     ram       2
# 788     ram       3
# 803     ram       1
# 824     ram       5
# 827     ram       2
# 831     ram       2
# 850     ram       6
# 869     ram       2

# %%
# How many passengers are less than 5 years old 
len(df[df['Age'] < 5 ])
# Out:
# 40

# %%
# number of passengers who are greater than in age 18
pp = len(df[df['Age'] > 18 ]) 
pp
# Out:
# 575

# %%
# how many passengers are less than 18 years old
len(df) - len(df[df['Age'] > 18 ])
# Out:
# 316

# %%
# How many childrens paid the fare 
df[df['Age'] < 5 ].Fare
# Out:
# 7       21.0750
# 10      16.7000
# 16      29.1250
# 43      41.5792
# 63      27.9000
# 78      29.0000
# 119     31.2750
# 164     39.6875
# 171     29.1250
# 172     11.1333
# 183     39.0000
# 184     22.0250
# 193     26.0000
# 205     10.4625
# 261     31.3875
# 297    151.5500
# 305    151.5500
# 340     26.0000
# 348     15.9000
# 374     21.0750
# 381     15.7417
# 386     46.9000
# 407     18.7500
# 445     81.8583
# 469     19.2583
# 479     12.2875
# 530     26.0000
# 618     39.0000
# 642     27.9000
# 644     19.2583
# 691     13.4167
# 750     23.0000
# 755     14.5000
# 788     20.5750
# 803      8.5167
# 824     39.6875
# 827     37.0042
# 831     18.7500
# 850     31.2750
# 869     11.1333
# Name: Fare, dtype: float64

# %%
# Question how many passengers paid less than avg fare 
df['Fare'].mean() 
# 32.2
# Out:
# 32.204207968574636

# %%
df.describe().mean() 
# Fare    192.32  
# above there are two different values because of missing values
# Out:
# PassengerId    478.044230
# Survived       111.733804
# Pclass         113.268089
# Age            115.596327
# SibSp          112.703219
# Parch          112.273456
# Fare           192.323930
# family         113.064758
# dtype: float64

# %%
len(df[df['Fare'] < df['Fare'].mean()]) 
# 680
# Out:
# 680

# %%
# How many passengers paid 0 fare 
len(df[df['Fare'] == 0]) 
# 15
# Out:
# 15

# %%
# show the name of passengers who paid 0 fare 
df[df['Fare'] == 0].Name
# Out:
# 179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object

# %%
# storing in list 
list(df[df['Fare'] == 0].Name)
# Out:
# ['Leonard, Mr. Lionel',
#  'Harrison, Mr. William',
#  'Tornquist, Mr. William Henry',
#  'Parkes, Mr. Francis "Frank"',
#  'Johnson, Mr. William Cahoone Jr',
#  'Cunningham, Mr. Alfred Fleming',
#  'Campbell, Mr. William',
#  'Frost, Mr. Anthony Wood "Archie"',
#  'Johnson, Mr. Alfred',
#  'Parr, Mr. William Henry Marsh',
#  'Watson, Mr. Ennis Hastings',
#  'Knight, Mr. Robert J',
#  'Andrews, Mr. Thomas Jr',
#  'Fry, Mr. Richard',
#  'Reuchlin, Jonkheer. John George']

# %%
# How many passengers are male and female 
len(df[df['Sex']=='male'])
# Out:
# 577

# %%
# How many passengers are female 
len(df[df['Sex']=='female'])
# Out:
# 314

# %%
# How many % passengers are male and female in percentage(use normalize=True)
df['Sex'].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
# How many % passengers are male
df['Sex'].value_counts(normalize=True).male
# Out:
# 0.6475869809203143

# %%
# How many passengers are female
df['Sex'].value_counts().female
# Out:
# 314

# %%
# How many passengers are of class 1 
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked new_col  family
# 1        0  PC 17599  71.2833          C85        C     ram       1
# 3        0    113803  53.1000         C123        S     ram       1
# 6        0     17463  51.8625          E46        S     ram       0
# 11       0    113783  26.5500         C103        S     ram       0
# 23       0    113788  35.5000           A6        S     ram       0
# ..     ...       ...      ...          ...      ...     ...     ...
# 871      1     11751  52.5542          D35        S     ram       2
# 872      0       695   5.0000  B51 B53 B55        S     ram       0
# 879      1     11767  83.1583          C50        C     ram       1
# 887      0    112053  30.0000          B42        S     ram       0
# 889      0    111369  30.0000         C148        C     ram       0
#
# [216 rows x 14 columns]

# %%
# How many passengers has survived 
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 1        0          PC 17599  71.2833   C85        C     ram       1
# 2        0  STON/O2. 3101282   7.9250   NaN        S     ram       0
# 3        0            113803  53.1000  C123        S     ram       1
# 8        2            347742  11.1333   NaN        S     ram       2
# 9        0            237736  30.0708   NaN        C     ram       1
# ..     ...               ...      ...   ...      ...     ...     ...
# 875      0              2667   7.2250   NaN        C     ram       0
# 879      1             11767  83.1583   C50        C     ram       1
# 880      1            230433  26.0000   NaN        S     ram       1
# 887      0            112053  30.0000   B42        S     ram       0
# 889      0            111369  30.0000  C148        C     ram       0
#
# [342 rows x 14 columns]

# %%
# % How many passengers has survived 
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
# how many female passenger AND paid more than avg fare 
df[(df['Sex'] == 'female') & (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch         Ticket      Fare Cabin Embarked new_col  family
# 1        0       PC 17599   71.2833   C85        C     ram       1
# 3        0         113803   53.1000  C123        S     ram       1
# 31       0       PC 17569  146.5208   B78        C     ram       1
# 43       2  SC/Paris 2123   41.5792   NaN        C     ram       3
# 52       0       PC 17572   76.7292   D33        C     ram       1
# ..     ...            ...       ...   ...      ...     ...     ...
# 853      1       PC 17592   39.4000   D28        S     ram       1
# 856      1          36928  164.8667   NaN        S     ram       2
# 863      2       CA. 2343   69.5500   NaN        S     ram      10
# 871      1          11751   52.5542   D35        S     ram       2
# 879      1          11767   83.1583   C50        C     ram       1
#
# [104 rows x 14 columns]

# %%
#Q how many passengers are male OR who paid greater than avg fare >> OR condition is used
#Q how many male passenger paid more than avg >> AND condition is used
df[(df['Sex'] == 'male') | (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked new_col  family
# 0        0         A/5 21171   7.2500   NaN        S     ram       1
# 1        0          PC 17599  71.2833   C85        C     ram       1
# 3        0            113803  53.1000  C123        S     ram       1
# 4        0            373450   8.0500   NaN        S     ram       0
# 5        0            330877   8.4583   NaN        Q     ram       0
# ..     ...               ...      ...   ...      ...     ...     ...
# 883      0  C.A./SOTON 34068  10.5000   NaN        S     ram       0
# 884      0   SOTON/OQ 392076   7.0500   NaN        S     ram       0
# 886      0            211536  13.0000   NaN        S     ram       0
# 889      0            111369  30.0000  C148        C     ram       0
# 890      0            370376   7.7500   NaN        Q     ram       0
#
# [681 rows x 14 columns]

# %%
# range of the fare 
max(df['Fare']) - min(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
min(df['Fare'])
# Out:
# 0.0

# %%
# who are the passengers who paid maximum fare 
df[df['Fare'] == max(df['Fare'])]['Name'] 

# home work :
# Q. How many passengers have parch(parent and children) greater than 3 
# Q. How many passengers who survived paid the maximum fare 
# Q. How many passenger who didn't survived was from class 1 
# Q. How many passengers are having children(<5 years old)
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# Access of data frame rows 
df[0:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# 62           63         0       1
# 64           65         0       1
# 66           67         1       2
# 68           69         1       3
# 70           71         0       2
# 72           73         0       2
# 74           75         1       3
# 76           77         0       3
# 78           79         1       2
# 80           81         0       3
# 82           83         1       3
# 84           85         1       2
# 86           87         0       3
# 88           89         1       1
# 90           91         0       3
# 92           93         0       1
# 94           95         0       3
# 96           97         0       1
# 98           99         1       2
#
#                                                  Name     Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.00      1
# 2                              Heikkinen, Miss. Laina  female  26.00      0
# 4                            Allen, Mr. William Henry    male  35.00      0
# 6                             McCarthy, Mr. Timothy J    male  54.00      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 12                     Saundercock, Mr. William Henry    male  20.00      0
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.00      0
# 16                               Rice, Master. Eugene    male   2.00      4
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.00      1
# 20                               Fynney, Mr. Joseph J    male  35.00      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.00      0
# 24                      Palsson, Miss. Torborg Danira  female   8.00      3
# 26                            Emir, Mr. Farred Chehab    male    NaN      0
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female    NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.00      0
# 32                           Glynn, Miss. Mary Agatha  female    NaN      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.00      1
# 36                                   Mamee, Mr. Hanna    male    NaN      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.00      2
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00      1
# 42                                Kraeff, Mr. Theodor    male    NaN      0
# 44                      Devaney, Miss. Margaret Delia  female  19.00      0
# 46                                  Lennon, Mr. Denis    male    NaN      1
# 48                                Samaan, Mr. Youssef    male    NaN      2
# 50                         Panula, Master. Juha Niilo    male   7.00      4
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.00      0
# 56                                  Rugg, Miss. Emily  female  21.00      0
# 58                       West, Miss. Constance Mirium  female   5.00      1
# 60                              Sirayanian, Mr. Orsen    male  22.00      0
# 62                        Harris, Mr. Henry Birkhardt    male  45.00      1
# 64                              Stewart, Mr. Albert A    male    NaN      0
# 66                       Nye, Mrs. (Elizabeth Ramell)  female  29.00      0
# 68                    Andersson, Miss. Erna Alexandra  female  17.00      4
# 70                         Jenkin, Mr. Stephen Curnow    male  32.00      0
# 72                               Hood, Mr. Ambrose Jr    male  21.00      0
# 74                                      Bing, Mr. Lee    male  32.00      0
# 76                                  Staneff, Mr. Ivan    male    NaN      0
# 78                      Caldwell, Master. Alden Gates    male   0.83      0
# 80                               Waelens, Mr. Achille    male  22.00      0
# 82                     McDermott, Miss. Brigdet Delia  female    NaN      0
# 84                                Ilett, Miss. Bertha  female  17.00      0
# 86                             Ford, Mr. William Neal    male  16.00      1
# 88                         Fortune, Miss. Mabel Helen  female  23.00      3
# 90                               Christmann, Mr. Emil    male  29.00      0
# 92                        Chaffee, Mr. Herbert Fuller    male  46.00      1
# 94                                  Coxon, Mr. Daniel    male  59.00      0
# 96                          Goldschmidt, Mr. George B    male  71.00      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.00      0
#
#     Parch            Ticket      Fare        Cabin Embarked new_col  family
# 0       0         A/5 21171    7.2500          NaN        S     ram       1
# 2       0  STON/O2. 3101282    7.9250          NaN        S     ram       0
# 4       0            373450    8.0500          NaN        S     ram       0
# 6       0             17463   51.8625          E46        S     ram       0
# 8       2            347742   11.1333          NaN        S     ram       2
# 10      1           PP 9549   16.7000           G6        S     ram       2
# 12      0         A/5. 2151    8.0500          NaN        S     ram       0
# 14      0            350406    7.8542          NaN        S     ram       0
# 16      1            382652   29.1250          NaN        Q     ram       5
# 18      0            345763   18.0000          NaN        S     ram       1
# 20      0            239865   26.0000          NaN        S     ram       0
# 22      0            330923    8.0292          NaN        Q     ram       0
# 24      1            349909   21.0750          NaN        S     ram       4
# 26      0              2631    7.2250          NaN        C     ram       0
# 28      0            330959    7.8792          NaN        Q     ram       0
# 30      0          PC 17601   27.7208          NaN        C     ram       0
# 32      0            335677    7.7500          NaN        Q     ram       0
# 34      0          PC 17604   82.1708          NaN        C     ram       1
# 36      0              2677    7.2292          NaN        C     ram       0
# 38      0            345764   18.0000          NaN        S     ram       2
# 40      0              7546    9.4750          NaN        S     ram       1
# 42      0            349253    7.8958          NaN        C     ram       0
# 44      0            330958    7.8792          NaN        Q     ram       0
# 46      0            370371   15.5000          NaN        Q     ram       1
# 48      0              2662   21.6792          NaN        C     ram       2
# 50      1           3101295   39.6875          NaN        S     ram       5
# 52      0          PC 17572   76.7292          D33        C     ram       1
# 54      1            113509   61.9792          B30        C     ram       1
# 56      0        C.A. 31026   10.5000          NaN        S     ram       0
# 58      2        C.A. 34651   27.7500          NaN        S     ram       3
# 60      0              2669    7.2292          NaN        C     ram       0
# 62      0             36973   83.4750          C83        S     ram       1
# 64      0          PC 17605   27.7208          NaN        C     ram       0
# 66      0        C.A. 29395   10.5000          F33        S     ram       0
# 68      2           3101281    7.9250          NaN        S     ram       6
# 70      0        C.A. 33111   10.5000          NaN        S     ram       0
# 72      0      S.O.C. 14879   73.5000          NaN        S     ram       0
# 74      0              1601   56.4958          NaN        S     ram       0
# 76      0            349208    7.8958          NaN        S     ram       0
# 78      2            248738   29.0000          NaN        S     ram       2
# 80      0            345767    9.0000          NaN        S     ram       0
# 82      0            330932    7.7875          NaN        Q     ram       0
# 84      0        SO/C 14885   10.5000          NaN        S     ram       0
# 86      3        W./C. 6608   34.3750          NaN        S     ram       4
# 88      2             19950  263.0000  C23 C25 C27        S     ram       5
# 90      0            343276    8.0500          NaN        S     ram       0
# 92      0       W.E.P. 5734   61.1750          E31        S     ram       1
# 94      0            364500    7.2500          NaN        S     ram       0
# 96      0          PC 17754   34.6542           A5        C     ram       0
# 98      1            231919   23.0000          NaN        S     ram       1

# %%
# 2 types of indexing 
# implicit index or natural index : pandas provide the internal/integer index 
# explicit index : we defined/named index 

df.iloc[0:2]   
# i is implicit or integer index 
# create integer index as location from 0 to 1 as location 
# provide the rows from 0 to 1  
# iloc always considers inbuilt indexs
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_col  family
# 0      0  A/5 21171   7.2500   NaN        S     ram       1
# 1      0   PC 17599  71.2833   C85        C     ram       1

# %%
df.loc[0:2]  
# loc location 
# loc is named/explicit index 
# provide the rows whose location is 0,1,2 
# loc always considers named indexs
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  family
# 0      0         A/5 21171   7.2500   NaN        S     ram       1
# 1      0          PC 17599  71.2833   C85        C     ram       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S     ram       0

# %%
#loc will go with named indexes, iloc will go with inbuilt index
df.iloc[0:2, ['Name', 'Sex', 'Age']] 
# iloc requires numeric index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df.iloc[0:2, ['Name', 'Sex', 'Age']]
#       2 # iloc requires numeric index
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
#    1651 def _getitem_tuple(self, tup: tuple):
# -> 1652     tup = self._validate_tuple_indexer(tup)
#    1653     with suppress(IndexingError):
#    1654         return self._getitem_lowerdim(tup)
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:940, in _LocationIndexer._validate_tuple_indexer(self, key)
#     938 for i, k in enumerate(key):
#     939     try:
# --> 940         self._validate_key(k, i)
#     941     except ValueError as err:
#     942         raise ValueError(
#     943             "Location based indexing can only have "
#     944             f"[{self._valid_types}] types"
#     945         ) from err
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:1570, in _iLocIndexer._validate_key(self, key, axis)
#    1568 # check that the key has a numeric dtype
#    1569 if not is_numeric_dtype(arr.dtype):
# -> 1570     raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1572 # check that the key does not exceed the maximum size of the index
#    1573 if len(arr) and (arr.max() >= len_axis or arr.min() < -len_axis):
#
# IndexError: .iloc requires numeric indexers, got ['Name' 'Sex' 'Age']

# %%
df.loc[0:2, ['Name', 'Sex', 'Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %%
df.iloc[0:2, 3:6] 
# can use iloc for column index by mentioning integers instead of names
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
len(df['Name'][2:14]) 
# 12
# Out:
# 12

# %%
# changing the index from integer to characters 
s = pd.Series(list(df['Name'][2:5]), index=['a','b','c']) 
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1=pd.Series(list(df['Name'][5:8])) 
s1
# Out:
# 0                  Moran, Mr. James
# 1           McCarthy, Mr. Timothy J
# 2    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s1
# error 
# series or dataframe doesn't work with + 
# but string can work with +
# Out:
# a    NaN
# b    NaN
# c    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# dtype: object

# %%
s2 = pd.Series(list(df['Name'][5:8]), index=['a','b','c']) 
s2
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s2 
# error 
# series or dataframe doesn't work with + 
# but string can work with +

# the strings are concatenated which is not expected
# Out:
# a                     Moran, Mr. JamesMoran, Mr. James
# b       McCarthy, Mr. Timothy JMcCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta LeonardPalsson, Master....
# dtype: object

# %%
s.append(s1) 
# works 
# recommended to use
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11024\1613966636.py in ?()
# ----> 1 s.append(s1)
#       2 # works
#       3 # recommended to use
#
# c:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'

# %%
df.drop('PassengerId')  #row>>axis=0, axis = 1>>columns
# error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 df.drop('PassengerId', axis=0)  #row>>axis=0, axis = 1>>columns
#       2 # error
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['PassengerId'] not found in axis"

# %%
df.drop('PassengerId', axis=1) 
# passenger id, 1st column dropped
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S     ram
# 2    26.0      0      0  STON/O2. 3101282   7.9250   NaN        S     ram
# 3    35.0      1      0            113803  53.1000  C123        S     ram
# 4    35.0      0      0            373450   8.0500   NaN        S     ram
# 5     NaN      0      0            330877   8.4583   NaN        Q     ram
# ..    ...    ...    ...               ...      ...   ...      ...     ...
# 886  27.0      0      0            211536  13.0000   NaN        S     ram
# 887  19.0      0      0            112053  30.0000   B42        S     ram
# 888   NaN      1      2        W./C. 6607  23.4500   NaN        S     ram
# 889  26.0      0      0            111369  30.0000  C148        C     ram
# 890  32.0      0      0            370376   7.7500   NaN        Q     ram
#
#      family
# 0         1
# 2         0
# 3         1
# 4         0
# 5         0
# ..      ...
# 886       0
# 887       0
# 888       3
# 889       0
# 890       0
#
# [890 rows x 13 columns]

# %%
df.drop(2, inplace=True) 

# by default row 1 is dropped 
# implace is True modifies the original data and cannot roll back

# %%
df
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1       1
# Allen, Mr. William Henry                                5         0       3
# Moran, Mr. James                                        6         0       3
# McCarthy, Mr. Timothy J                                 7         0       1
# Palsson, Master. Gosta Leonard                          8         0       3
# ...                                                   ...       ...     ...
# Montvila, Rev. Juozas                                 887         0       2
# Graham, Miss. Margaret Edith                          888         1       1
# Johnston, Miss. Catherine Helen "Carrie"              889         0       3
# Behr, Mr. Karl Howell                                 890         1       1
# Dooley, Mr. Patrick                                   891         0       3
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# Allen, Mr. William Henry                        male  35.0      0      0
# Moran, Mr. James                                male   NaN      0      0
# McCarthy, Mr. Timothy J                         male  54.0      0      0
# Palsson, Master. Gosta Leonard                  male   2.0      3      1
# ...                                              ...   ...    ...    ...
# Montvila, Rev. Juozas                           male  27.0      0      0
# Graham, Miss. Margaret Edith                  female  19.0      0      0
# Johnston, Miss. Catherine Helen "Carrie"      female   NaN      1      2
# Behr, Mr. Karl Howell                           male  26.0      0      0
# Dooley, Mr. Patrick                             male  32.0      0      0
#
#                                                   Ticket     Fare Cabin  \
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)      113803  53.1000  C123
# Allen, Mr. William Henry                          373450   8.0500   NaN
# Moran, Mr. James                                  330877   8.4583   NaN
# McCarthy, Mr. Timothy J                            17463  51.8625   E46
# Palsson, Master. Gosta Leonard                    349909  21.0750   NaN
# ...                                                  ...      ...   ...
# Montvila, Rev. Juozas                             211536  13.0000   NaN
# Graham, Miss. Margaret Edith                      112053  30.0000   B42
# Johnston, Miss. Catherine Helen "Carrie"      W./C. 6607  23.4500   NaN
# Behr, Mr. Karl Howell                             111369  30.0000  C148
# Dooley, Mr. Patrick                               370376   7.7500   NaN
#
#                                              Embarked new_col  family
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        S     ram       1
# Allen, Mr. William Henry                            S     ram       0
# Moran, Mr. James                                    Q     ram       0
# McCarthy, Mr. Timothy J                             S     ram       0
# Palsson, Master. Gosta Leonard                      S     ram       4
# ...                                               ...     ...     ...
# Montvila, Rev. Juozas                               S     ram       0
# Graham, Miss. Margaret Edith                        S     ram       0
# Johnston, Miss. Catherine Helen "Carrie"            S     ram       3
# Behr, Mr. Karl Howell                               C     ram       0
# Dooley, Mr. Patrick                                 Q     ram       0
#
# [888 rows x 13 columns]

# %%
# df.drop() # what ever rows we have will treat as named indexed

# %%
df.set_index('Cabin') 

# earlier it is implicit index now it is set as name index 
# useful in time series data when we want to set month as index
# Out:
#        PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# Cabin
# C123             4         1       1  female  35.0      1      0      113803
# NaN              5         0       3    male  35.0      0      0      373450
# NaN              6         0       3    male   NaN      0      0      330877
# E46              7         0       1    male  54.0      0      0       17463
# NaN              8         0       3    male   2.0      3      1      349909
# ...            ...       ...     ...     ...   ...    ...    ...         ...
# NaN            887         0       2    male  27.0      0      0      211536
# B42            888         1       1  female  19.0      0      0      112053
# NaN            889         0       3  female   NaN      1      2  W./C. 6607
# C148           890         1       1    male  26.0      0      0      111369
# NaN            891         0       3    male  32.0      0      0      370376
#
#           Fare Embarked new_col  family
# Cabin
# C123   53.1000        S     ram       1
# NaN     8.0500        S     ram       0
# NaN     8.4583        Q     ram       0
# E46    51.8625        S     ram       0
# NaN    21.0750        S     ram       4
# ...        ...      ...     ...     ...
# NaN    13.0000        S     ram       0
# B42    30.0000        S     ram       0
# NaN    23.4500        S     ram       3
# C148   30.0000        C     ram       0
# NaN     7.7500        Q     ram       0
#
# [888 rows x 12 columns]

# %%
df
# still Cabin column is not set in original index
# Out:
#        PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# Cabin
# C123             4         1       1  female  35.0      1      0      113803
# NaN              5         0       3    male  35.0      0      0      373450
# NaN              6         0       3    male   NaN      0      0      330877
# E46              7         0       1    male  54.0      0      0       17463
# NaN              8         0       3    male   2.0      3      1      349909
# ...            ...       ...     ...     ...   ...    ...    ...         ...
# NaN            887         0       2    male  27.0      0      0      211536
# B42            888         1       1  female  19.0      0      0      112053
# NaN            889         0       3  female   NaN      1      2  W./C. 6607
# C148           890         1       1    male  26.0      0      0      111369
# NaN            891         0       3    male  32.0      0      0      370376
#
#           Fare Embarked new_col  family
# Cabin
# C123   53.1000        S     ram       1
# NaN     8.0500        S     ram       0
# NaN     8.4583        Q     ram       0
# E46    51.8625        S     ram       0
# NaN    21.0750        S     ram       4
# ...        ...      ...     ...     ...
# NaN    13.0000        S     ram       0
# B42    30.0000        S     ram       0
# NaN    23.4500        S     ram       3
# C148   30.0000        C     ram       0
# NaN     7.7500        Q     ram       0
#
# [888 rows x 12 columns]

# %%
# df.set_index('Cabin', inplace=True) # Cabin has set as original index by using inplace=True
df
# Out:
#        PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# Cabin
# C123             4         1       1  female  35.0      1      0      113803
# NaN              5         0       3    male  35.0      0      0      373450
# NaN              6         0       3    male   NaN      0      0      330877
# E46              7         0       1    male  54.0      0      0       17463
# NaN              8         0       3    male   2.0      3      1      349909
# ...            ...       ...     ...     ...   ...    ...    ...         ...
# NaN            887         0       2    male  27.0      0      0      211536
# B42            888         1       1  female  19.0      0      0      112053
# NaN            889         0       3  female   NaN      1      2  W./C. 6607
# C148           890         1       1    male  26.0      0      0      111369
# NaN            891         0       3    male  32.0      0      0      370376
#
#           Fare Embarked new_col  family
# Cabin
# C123   53.1000        S     ram       1
# NaN     8.0500        S     ram       0
# NaN     8.4583        Q     ram       0
# E46    51.8625        S     ram       0
# NaN    21.0750        S     ram       4
# ...        ...      ...     ...     ...
# NaN    13.0000        S     ram       0
# B42    30.0000        S     ram       0
# NaN    23.4500        S     ram       3
# C148   30.0000        C     ram       0
# NaN     7.7500        Q     ram       0
#
# [888 rows x 12 columns]

# %%
df.loc['C148']
# Out:
# PassengerId       890
# Survived            1
# Pclass              1
# Sex              male
# Age              26.0
# SibSp               0
# Parch               0
# Ticket         111369
# Fare             30.0
# Embarked            C
# new_col           ram
# family              0
# Name: C148, dtype: object

# %%
# pandas still having implicit indexing 
df.loc[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 2
#       1 # pandas still having implicit indexing
# ----> 2 df.loc[3]
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File c:\Python311\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File c:\Python311\Lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 3

# %%
df.reset_index(inplace=True) 
# if we perform reset index will get implicit/index  

df
# Out:
#     Cabin  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0    C123            4         1       1  female  35.0      1      0
# 1     NaN            5         0       3    male  35.0      0      0
# 2     NaN            6         0       3    male   NaN      0      0
# 3     E46            7         0       1    male  54.0      0      0
# 4     NaN            8         0       3    male   2.0      3      1
# ..    ...          ...       ...     ...     ...   ...    ...    ...
# 883   NaN          887         0       2    male  27.0      0      0
# 884   B42          888         1       1  female  19.0      0      0
# 885   NaN          889         0       3  female   NaN      1      2
# 886  C148          890         1       1    male  26.0      0      0
# 887   NaN          891         0       3    male  32.0      0      0
#
#          Ticket     Fare Embarked new_col  family
# 0        113803  53.1000        S     ram       1
# 1        373450   8.0500        S     ram       0
# 2        330877   8.4583        Q     ram       0
# 3         17463  51.8625        S     ram       0
# 4        349909  21.0750        S     ram       4
# ..          ...      ...      ...     ...     ...
# 883      211536  13.0000        S     ram       0
# 884      112053  30.0000        S     ram       0
# 885  W./C. 6607  23.4500        S     ram       3
# 886      111369  30.0000        C     ram       0
# 887      370376   7.7500        Q     ram       0
#
# [888 rows x 13 columns]

# %%
# make dataframe is dictionary 
d={"key1":[2,3,4,5], "key2":[4,5,6,7]  } 
pd.DataFrame(d)
# Out:
#    key1  key2
# 0     2     4
# 1     3     5
# 2     4     6
# 3     5     7

# %%
# make dataframe is tuple 

d={"key1":(2,3,4,5),

   "key2":(4,5,6,7) 
   } 

pd.DataFrame(d)
# Out:
#    key1  key2
# 0     2     4
# 1     3     5
# 2     4     6
# 3     5     7

# %%
df1 = pd.read_csv(r"C:\Users\ramki\Downloads\03rd_04th_Feb\03rd_04th_Feb\taxonomy.csv.xls")
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.dtypes
# Out:
# taxonomy_id    object
# name           object
# parent_id      object
# parent_name    object
# dtype: object

# %%
df1.isnull().sum() 
# given null values of all columns
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.dropna() 
# drop null values row wise
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
#if axis =1 then column wise drop null values 
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
# drop null values for specific column 
df1[['name']].dropna(axis=1)
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
# don't drop null values fill with some random data 
df1.fillna("missing lalalalalalalalala")
# Out:
#     taxonomy_id                          name                   parent_id  \
# 0           101                     Emergency  missing lalalalalalalalala
# 1        101-01             Disaster Response                         101
# 2        101-02                Emergency Cash                         101
# 3     101-02-01             Help Pay for Food                      101-02
# 4     101-02-02       Help Pay for Healthcare                      101-02
# ..          ...                           ...                         ...
# 285   111-01-07              Workplace Rights                      111-01
# 286      111-02                     Mediation                         111
# 287      111-03                        Notary                         111
# 288      111-04                Representation                         111
# 289      111-05  Translation & Interpretation                         111
#
#                     parent_name
# 0    missing lalalalalalalalala
# 1                     Emergency
# 2                     Emergency
# 3                Emergency Cash
# 4                Emergency Cash
# ..                          ...
# 285        Advocacy & Legal Aid
# 286                       Legal
# 287                       Legal
# 288                       Legal
# 289                       Legal
#
# [290 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
#Q what is the average fare paid by people who survived?
#groupby >> https://www.w3resource.com/python-exercises/pandas/groupby/index.php

# %%
# what is avg fare paid by people who survived? 

# groupby based on one column 

# group by : Interview question how group by works 

# https://www.w3resource.com/python-exercises/pandas/groupby/index.php
# group the data based on column called ID 
# if we want to group + by split by unique values of x,y,z from image given 
# next step do aggregation seperatly for x , y , z 
# combine the x,y,z 

df.groupby('Survived').mean(numeric_only=True) #for recent pandas version
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0          447.830292  2.531022  30.646572  0.552920  0.330292  22.145018
# 1          446.967647  1.950000  28.318299  0.473529  0.467647  48.447121
#
#             family
# Survived
# 0         0.883212
# 1         0.941176

# %%
# df.groupby('Survived').mean() # may be mean was depricated
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
# df.groupby('Survived').max()
# df.groupby('Survived').min()
# max and min was depricated

df.groupby('Survived').sum()
# Out:
#                                                       Cabin  PassengerId  \
# Survived
# 0         E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...       245411
# 1         C123G6C103D56A6B78D33C52B28F33C23 C25 C27D10 D...       151969
#
#           Pclass                                                Sex       Age  \
# Survived
# 0           1387  malemalemalemalemalemalefemalemalefemalemalefe...  12963.50
# 1            663  femalefemalefemalefemalefemalefemalemalefemale...   8155.67
#
#           SibSp  Parch                                             Ticket  \
# Survived
# 0           303    181  37345033087717463349909A/5. 215134708235040638...
# 1           161    159  113803347742237736PP 9549113783248706244373264...
#
#                 Fare                                           Embarked  \
# Survived
# 0         12135.4699  SQSSSSSQSSSCSSCSCSSSSSCSQCSSSCCSCSSCSSSSSCSSSS...
# 1         16472.0211  SSCSSSSCSQSSQCQCCCQQCSSSSCSSSSSSQSSSCSSSQSCSCS...
#
#                                                     new_col  family
# Survived
# 0         ramramramramramramramramramramramramramramramr...     484
# 1         ramramramramramramramramramramramramramramramr...     320

# %%
# df.groupby('Survived').aggregate([min, 'max', 'mean', 'median', 'count', np.std, 'var'])

# aggregate was depricated

# %%
#groupby with two columns
#Q. Total how many people are there in survived for each sex, pclass

df.groupby(['Sex', 'Pclass'])['Survived'].sum() # suming up of survived column of 0 and 1
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         71
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
# if don't want to sum survived column of 0 and 1
# then include 'Survived inside group by'
df.groupby(['Sex', 'Pclass', 'Survived']).sum()
# Out:
#                                                                     Cabin  \
# Sex    Pclass Survived
# female 1      0                                         C49C22 C26C22 C26
#               1         C123C103B78D33B28C23 C25 C27D47C2E33B4B80D36D1...
#        2      0                                                       E77
#               1                                 F33E101E101DF33DF33F4E101
#        3      0                                                      G6G6
#               1                                             G6F E69G6E121
# male   1      0         E46C23 C25 C27B30C83E31A5D26C110B58 B60D26C123...
#               1         A6C52D10 D12A31C93D35C106C22 C26E50B96 B98C52A...
#        2      0                                                       F2D
#               1                                                 D56F4F2F2
#        3      0                                        F G73F G63F G73F38
#               1                                                   E10E121
#
#                         PassengerId      Age  SibSp  Parch  \
# Sex    Pclass Survived
# female 1      0                 975    77.00      2      4
#               1               43129  2827.00     49     39
#        2      0                2541   216.00      3      1
#               1               31135  1909.50     34     45
#        3      0               31707  1310.00     93     79
#               1               25851   882.50     36     36
# male   1      0               31849  2719.50     21     20
#               1               23750  1449.92     17     14
#        2      0               41315  2803.00     28     13
#               1                7065   240.33      9     11
#        3      0              137024  5838.00    156     64
#               1               21039   846.42     16     14
#
#                                                                    Ticket  \
# Sex    Pclass Survived
# female 1      0                                      PC 17595113781113781
#               1         113803113783PC 17569PC 17572113572199501175211...
#        2      0                  11668248747250651237671S.O./P.P. 3244252
#               1         237736248706SC/Paris 21232926C.A. 31026C.A. 34...
#        3      0         3504063457633499093457647546349237CA 214434924...
#               1         347742PP 9549264933092334707733095933567726513...
# male   1      0         1746319950PC 17601PC 1760411378911350936973PC ...
#               1         11378819947PC 17759111428112277199431175119988...
#        2      0         239865C.A. 24579C.A. 33111S.O.C. 1487924436711...
#               1         244373248698248738230136230080SW/PP 7512377982...
#        3      0         373450330877349909A/5. 21513470823826522631349...
#               1         2677266116013457793129912651C 1736935004336329...
#
#                              Fare  \
# Sex    Pclass Survived
# female 1      0          331.8125
#               1         9572.7292
#        2      0          109.5000
#               1         1560.2292
#        3      0         1423.6627
#               1          889.5209
# male   1      0         4842.9081
#               1         3358.6794
#        2      0         1773.4958
#               1          358.6167
#        3      0         3654.0908
#               1          732.2457
#
#                                                                  Embarked  \
# Sex    Pclass Survived
# female 1      0                                                       CSS
#               1         SSCCSSSSCCCCSCSCSSSSCCCCCCCSCCCSCSSCCCCSCQSSSC...
#        2      0                                                    SSSSSS
#               1         CSCSSSSSSSSSSSSSSSQSQSSSSSCSSSSSSSSSSSSCSSSSSS...
#        3      0         SSSSSSSSCSCSSCSSSSSSCSSSQSSCSSSSSSSSSSSQQSSSSS...
#               1         SSCQSQQCQQSSQSSQCSSQSSQSQQSSQCQSQQSSQSQQCQSCSS...
# male   1      0         SSCCSCSCSSCSSCSSCCSSCSQSSSSCSCSSSSSCCSSCSSSSCS...
#               1             SSCSCSSSSCSSSSSCSCSSCSCCCSSSCCCSCCSSSSSCSSCSC
#        2      0         SSSSSSSCSCSSSSSSCSSSSSSSSSSSSSSSCCSSSSSCSSSSSS...
#               1                                         SSSSSSSSSSCSSSSCS
#        3      0         SQSSSQCSSCSQCSSCSCSSSCSSSSSSSSSSSSSSSSSSSQSQSC...
#               1           CCSSSCSSSSCSSSSSSQSSSSSSSCSSQCSSCSSSCSSCSCSSQSS
#
#                                                                   new_col  \
# Sex    Pclass Survived
# female 1      0                                                 ramramram
#               1         ramramramramramramramramramramramramramramramr...
#        2      0                                        ramramramramramram
#               1         ramramramramramramramramramramramramramramramr...
#        3      0         ramramramramramramramramramramramramramramramr...
#               1         ramramramramramramramramramramramramramramramr...
# male   1      0         ramramramramramramramramramramramramramramramr...
#               1         ramramramramramramramramramramramramramramramr...
#        2      0         ramramramramramramramramramramramramramramramr...
#               1         ramramramramramramramramramramramramramramramr...
#        3      0         ramramramramramramramramramramramramramramramr...
#               1         ramramramramramramramramramramramramramramramr...
#
#                         family
# Sex    Pclass Survived
# female 1      0              6
#               1             88
#        2      0              4
#               1             79
#        3      0            172
#               1             72
# male   1      0             41
#               1             31
#        2      0             41
#               1             20
#        3      0            220
#               1             30

# %%
#To convert the result to dataframe
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             71
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().unstack()
# Out:
# Pclass   1   2   3
# Sex
# female  90  70  71
# male    45  17  47

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
# library : multiple modules and multiple packages 

# module : notebook 

# package : multiple modules 

 
# Thought process : 
# 1. read data 
# 2. understood data 
# 3. business understanding of data(business team) : first 5 and last 5 rows 
# 4. statistical check
